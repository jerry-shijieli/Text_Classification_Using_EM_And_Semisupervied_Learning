# %% [markdown]
# Update: Increase experiment points

# %%
# Import packages and libraries
import numpy as np
import random as rnd
import re
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, StratifiedKFold, ShuffleSplit
from sklearn import metrics

from time import time
from pprint import pprint
from copy import deepcopy
from wordcloud import WordCloud 
from Semi_EM_NB import Semi_EM_MultinomialNB
from os import path
from PIL import Image

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
def remove_noise(sentence):
    result = ''
    poster = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    stopword_set = set(stopwords.words('english'))
    wordlist = re.sub(r"\n|(\\(.*?){)|}|[!$%^&*#()_+|~\-={}\[\]:\";'<>?,.\/\\]|[0-9]|[@]", ' ', sentence) # remove punctuation
    wordlist = re.sub('\s+', ' ', wordlist) # remove extra space
    wordlist_normal = [poster.stem(word.lower()) for word in wordlist.split()] # restore word to its original form (stemming)
    wordlist_normal = [lemmatizer.lemmatize(word, pos='v') for word in wordlist_normal] # restore word to its root form (lemmatization)
    wordlist_clean = [word for word in wordlist_normal if word not in stopword_set] # remove stopwords
    result = ' '.join(wordlist_clean)
    return result

# %%
def cross_validation(clf, data_X, data_y, unlabeled=None, n_folds=5):
    print('=' * 80)
    print("Validation: ")
    print(clf)
    kf = StratifiedKFold(n_splits=n_folds)
    start_time = time()
    train_scores = list() # training accuracy
    fold_count = 1
    original_clf = deepcopy(clf)
    avg_accuracy = 0
    for train_ids, valid_ids in kf.split(data_X, data_y):
        cv_clf = deepcopy(original_clf)
        print("Fold # %d" % fold_count)
        fold_count += 1
        train_X, train_y, valid_X, valid_y = data_X[train_ids], data_y[train_ids], data_X[valid_ids], data_y[valid_ids]
        if unlabeled==None:
            cv_clf.fit(train_X, train_y)
        else:
            cv_clf.fit(train_X, train_y, unlabeled)
        pred = cv_clf.predict(valid_X)
        scores = dict()
        scores['accuracy'] = metrics.accuracy_score(valid_y, pred)
        scores['recall'] = metrics.recall_score(valid_y, pred, average='macro')
        scores['precision'] = metrics.precision_score(valid_y, pred, average='macro')
        scores['f1_score'] = metrics.f1_score(valid_y, pred, average='macro')
        train_scores.append(scores)
        avg_accuracy += scores['accuracy']
    train_time = time() - start_time
    print("Validation time: %0.3f seconds" % train_time)
    print("Average training accuracy: %0.3f" % (avg_accuracy/n_folds))
    return train_scores, train_time

# %%
def show_topK(classifier, vectorizer, categories, K=10):
    feature_names = np.asarray(vectorizer.get_feature_names())
    nrows, ncols = 5, 4
    fig, axes = plt.subplots(figsize=(50, 40), nrows=nrows, ncols=ncols)
    #d = path.dirname(__file__)
    circle_mask = np.array(Image.open(path.join('./', "circle.png")))
    for i, category in enumerate(categories):
        topK = np.argsort(classifier.coef_[i])[-K:]
        text = " ".join(feature_names[topK])
        print("%s: %s" % (category, text))
        wordcloud = WordCloud(background_color="white", mask=circle_mask).generate(text)
        axes[i//ncols, i%ncols].imshow(wordcloud, cmap=plt.cm.cool_r, interpolation='bilinear')
        axes[i//ncols, i%ncols].axis("off")
        axes[i//ncols, i%ncols].set_title(category, fontweight="bold", size=24)
    plt.show()

# %%
# Load data set with class labels and split into train and test set
test_size_ratio = 0.2
data_Xy = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'), shuffle=True)
category_names = data_Xy.target_names # text names of all categories
train_X, test_X, train_y, test_y = train_test_split(data_Xy.data, data_Xy.target, test_size=test_size_ratio, stratify=data_Xy.target)
print("Training set size: %8d\tTest set size: %8d" % (len(train_X), len(test_X)))
# Out:
# Training set size:    15076	Test set size:     3770

# %%
# preprocess train and test text data
train_X_clean = map(remove_noise, train_X)
test_X_clean = map(remove_noise, test_X)

# %%
# Convert all text data into tf-idf vectors 
vectorizer = TfidfVectorizer(stop_words='english', min_df=5, max_df=0.95)
# vectorizer = TfidfVectorizer()
train_vec = vectorizer.fit_transform(train_X_clean)
test_vec = vectorizer.transform(test_X_clean)
print train_vec.shape, test_vec.shape
# Out:
# (15076, 13155) (3770, 13155)

# %%
# Divide train data set into labeled and unlabeled data sets
split_ratio = 0.2 # labeled vs total(labeled+unlabeled)
# X_l, X_u, y_l, y_u = train_test_split(train_vec, train_y, train_size=split_ratio, stratify=train_y)
X_l, X_u, y_l, y_u = train_test_split(train_vec, train_y, test_size=10000, stratify=train_y)
experiments = np.logspace(2.3, 3.7, num=20, base=10, dtype='int')
print X_l.shape, X_u.shape
# Out:
# (5076, 13155) (10000, 13155)

# %%
# Cross validation for Naive Bayes classifier 
# using labeled data set only
nb_cv_scores = list()
nb_cv_times = list()
for n_l_docs in experiments:
    nb_clf = MultinomialNB(alpha=1e-2)
    cv_scores, cv_time = cross_validation(nb_clf, X_l[:n_l_docs,], y_l[:n_l_docs])
    nb_cv_scores.append(cv_scores)
    nb_cv_times.append(cv_time)
    print("Number of labeled documents: %6d" % n_l_docs)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.093 seconds
# Average training accuracy: 0.380
# Number of labeled documents:    199
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.061 seconds
# Average training accuracy: 0.366
# Number of labeled documents:    236
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.061 seconds
# Average training accuracy: 0.410
# Number of labeled documents:    280
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.063 seconds
# Average training accuracy: 0.418
# Number of labeled documents:    331
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.065 seconds
# Average training accuracy: 0.446
# Number of labeled documents:    393
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.055 seconds
# Average training accuracy: 0.437
# Number of labeled documents:    466
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.055 seconds
# Average training accuracy: 0.466
# Number of labeled documents:    552
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.062 seconds
# Average training accuracy: 0.503
# Number of labeled documents:    654
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.068 seconds
# Average training accuracy: 0.535
# Number of labeled documents:    775
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.066 seconds
# Average training accuracy: 0.563
# Number of labeled documents:    918
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.089 seconds
# Average training accuracy: 0.584
# Number of labeled documents:   1088
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.113 seconds
# Average training accuracy: 0.601
# Number of labeled documents:   1289
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.099 seconds
# Average training accuracy: 0.620
# Number of labeled documents:   1528
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.118 seconds
# Average training accuracy: 0.636
# Number of labeled documents:   1810
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.130 seconds
# Average training accuracy: 0.639
# Number of labeled documents:   2145
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.148 seconds
# Average training accuracy: 0.662
# Number of labeled documents:   2542
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.096 seconds
# Average training accuracy: 0.668
# Number of labeled documents:   3012
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.095 seconds
# Average training accuracy: 0.685
# Number of labeled documents:   3569
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.120 seconds
# Average training accuracy: 0.688
# Number of labeled documents:   4229
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.102 seconds
# Average training accuracy: 0.699
# Number of labeled documents:   5011
# /Users/Jerry/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Jerry/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Cross validation for semisupervised EM Naive Bayes classifier 
# using both labeled and unlabeled data set
em_nb_cv_scores = list()
em_nb_cv_times = list()
for n_l_docs in experiments:
    em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False) # semi supervised EM based Naive Bayes classifier
    cv_scores, cv_time = cross_validation(em_nb_clf, X_l[:n_l_docs,], y_l[:n_l_docs], X_u)
    em_nb_cv_scores.append(cv_scores)
    em_nb_cv_times.append(cv_time)
    print("Number of labeled documents: %6d" % n_l_docs)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 149.653 seconds
# Average training accuracy: 0.419
# Number of labeled documents:    199
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 145.068 seconds
# Average training accuracy: 0.441
# Number of labeled documents:    236
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 123.246 seconds
# Average training accuracy: 0.463
# Number of labeled documents:    280
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 126.435 seconds
# Average training accuracy: 0.462
# Number of labeled documents:    331
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 108.529 seconds
# Average training accuracy: 0.497
# Number of labeled documents:    393
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 118.863 seconds
# Average training accuracy: 0.511
# Number of labeled documents:    466
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 111.272 seconds
# Average training accuracy: 0.566
# Number of labeled documents:    552
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 99.485 seconds
# Average training accuracy: 0.592
# Number of labeled documents:    654
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 109.585 seconds
# Average training accuracy: 0.602
# Number of labeled documents:    775
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 86.938 seconds
# Average training accuracy: 0.619
# Number of labeled documents:    918
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 84.622 seconds
# Average training accuracy: 0.635
# Number of labeled documents:   1088
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 84.648 seconds
# Average training accuracy: 0.648
# Number of labeled documents:   1289
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 97.692 seconds
# Average training accuracy: 0.654
# Number of labeled documents:   1528
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 83.647 seconds
# Average training accuracy: 0.679
# Number of labeled documents:   1810
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 74.311 seconds
# Average training accuracy: 0.675
# Number of labeled documents:   2145
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 68.003 seconds
# Average training accuracy: 0.681
# Number of labeled documents:   2542
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 80.003 seconds
# Average training accuracy: 0.692
# Number of labeled documents:   3012
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 76.584 seconds
# Average training accuracy: 0.700
# Number of labeled documents:   3569
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 64.966 seconds
# Average training accuracy: 0.700
# Number of labeled documents:   4229
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 66.825 seconds
# Average training accuracy: 0.706
# Number of labeled documents:   5011

# %%
# plot CV accuracy comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['accuracy'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['accuracy'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_score_mean, color='b', linewidth=2, label='Traditional Naive Bayes')
ax.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax.plot(experiments, em_nb_score_mean, color='r', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Accuracy')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Cross-Validation Average Accuracy vs Number of Labeled Documents in Training Set')

# %%
# plot CV F1 Score comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['f1_score'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['f1_score'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_score_mean, color='b', linestyle='--', linewidth=2, label='Traditional Naive Bayes')
ax.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax.plot(experiments, em_nb_score_mean, color='r', linestyle='--', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='lightgreen')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('F1 Score')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Cross-Validation Average F1 Score vs Number of Labeled Documents in Training Set')

# %%
# plot CV accuracy comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['recall'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['recall'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(121)
ax1.plot(experiments, nb_score_mean, color='b', linestyle='-.', linewidth=2, label='Traditional Naive Bayes')
ax1.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax1.plot(experiments, em_nb_score_mean, color='r', linestyle='-.', linewidth=2, label='Semisupervised EM Naive Bayes')
ax1.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax1.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='pink')
ax1.set_xlabel('Number of Labeled Documents')
ax1.set_ylabel('Recall')
ax1.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax1.set_xscale('log')
ax1.set_xticks([200, 1000, 5000]) 
ax1.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['precision'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['precision'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
ax2 = fig.add_subplot(122)
ax2.plot(experiments, nb_score_mean, color='b', linestyle=':', linewidth=2, label='Traditional Naive Bayes')
ax2.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax2.plot(experiments, em_nb_score_mean, color='r', linestyle=':', linewidth=2, label='Semisupervised EM Naive Bayes')
ax2.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax2.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='aqua')
ax2.set_xlabel('Number of Labeled Documents')
ax2.set_ylabel('Precision')
ax2.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax2.set_xscale('log')
ax2.set_xticks([200, 1000, 5000]) 
ax2.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
fig.suptitle('Cross-Validation Recall and Precision vs Number of Labeled Documents in Training Set')
plt.show()

# %%
# plot time consuming in EM NB training process
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_cv_times, color='b', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_cv_times, color='r', linestyle='-', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.fill_between(experiments, nb_cv_times, em_nb_cv_times, color='beige')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Time (seconds)')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.title('Time consumed in  vs Number of Labeled Documents in Training Set')

# %%
# Evaluate original NB classifier using test data set
nb_test_scores = dict()
nb_test_scores['accuracy'] = list()
nb_test_scores['recall'] = list()
nb_test_scores['precision'] = list()
nb_test_scores['f1_score'] = list()
for n_l_docs in experiments:
    nb_clf = MultinomialNB(alpha=1e-2).fit(X_l[:n_l_docs,], y_l[:n_l_docs])
    pred = nb_clf.predict(test_vec)
    accuracy = metrics.accuracy_score(test_y, pred)
    nb_test_scores['accuracy'].append(accuracy)
    nb_test_scores['recall'].append(metrics.recall_score(test_y, pred, average='macro'))
    nb_test_scores['precision'].append(metrics.precision_score(test_y, pred, average='macro'))
    nb_test_scores['f1_score'].append(metrics.f1_score(test_y, pred, average='macro'))
    print("%6d labeled documents lead to accuracy of %.3f" % (n_l_docs, accuracy))
# Out:
#    199 labeled documents lead to accuracy of 0.363
#    236 labeled documents lead to accuracy of 0.368
#    280 labeled documents lead to accuracy of 0.388
#    331 labeled documents lead to accuracy of 0.410
#    393 labeled documents lead to accuracy of 0.432
#    466 labeled documents lead to accuracy of 0.464
#    552 labeled documents lead to accuracy of 0.503
#    654 labeled documents lead to accuracy of 0.547
#    775 labeled documents lead to accuracy of 0.564
#    918 labeled documents lead to accuracy of 0.593
#   1088 labeled documents lead to accuracy of 0.603
#   1289 labeled documents lead to accuracy of 0.615
#   1528 labeled documents lead to accuracy of 0.624
#   1810 labeled documents lead to accuracy of 0.644
#   2145 labeled documents lead to accuracy of 0.659
#   2542 labeled documents lead to accuracy of 0.667
#   3012 labeled documents lead to accuracy of 0.669
#   3569 labeled documents lead to accuracy of 0.683
#   4229 labeled documents lead to accuracy of 0.692
#   5011 labeled documents lead to accuracy of 0.703

# %%
# Evaluate semi-supervised EM NB classifier using test data set
em_nb_test_scores = dict()
em_nb_test_scores['accuracy'] = list()
em_nb_test_scores['recall'] = list()
em_nb_test_scores['precision'] = list()
em_nb_test_scores['f1_score'] = list()
for n_l_docs in experiments:
    em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False).fit(X_l[:n_l_docs,], y_l[:n_l_docs], X_u)
    pred = em_nb_clf.predict(test_vec)
    accuracy = metrics.accuracy_score(test_y, pred)
    em_nb_test_scores['accuracy'].append(accuracy)
    em_nb_test_scores['recall'].append(metrics.recall_score(test_y, pred, average='macro'))
    em_nb_test_scores['precision'].append(metrics.precision_score(test_y, pred, average='macro'))
    em_nb_test_scores['f1_score'].append(metrics.f1_score(test_y, pred, average='macro'))
    print("%6d labeled documents lead to accuracy of %.3f" % (n_l_docs, accuracy))
# Out:
#    199 labeled documents lead to accuracy of 0.444
#    236 labeled documents lead to accuracy of 0.455
#    280 labeled documents lead to accuracy of 0.455
#    331 labeled documents lead to accuracy of 0.481
#    393 labeled documents lead to accuracy of 0.503
#    466 labeled documents lead to accuracy of 0.546
#    552 labeled documents lead to accuracy of 0.592
#    654 labeled documents lead to accuracy of 0.626
#    775 labeled documents lead to accuracy of 0.640
#    918 labeled documents lead to accuracy of 0.663
#   1088 labeled documents lead to accuracy of 0.668
#   1289 labeled documents lead to accuracy of 0.670
#   1528 labeled documents lead to accuracy of 0.678
#   1810 labeled documents lead to accuracy of 0.680
#   2145 labeled documents lead to accuracy of 0.688
#   2542 labeled documents lead to accuracy of 0.694
#   3012 labeled documents lead to accuracy of 0.693
#   3569 labeled documents lead to accuracy of 0.702
#   4229 labeled documents lead to accuracy of 0.705
#   5011 labeled documents lead to accuracy of 0.711

# %%
# Plot and compare test accuracy metrics
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_test_scores['accuracy'], color='b', marker='s', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_test_scores['accuracy'], color='r', marker='o', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Accuracy')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Test Accuracy vs Number of Labeled Documents in Training Set')

# %%
# Plot and compare test f1 score metrics
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_test_scores['f1_score'], color='b', marker='s', linestyle='--', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_test_scores['f1_score'], color='r', marker='o', linestyle='--', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.fill_between(experiments, nb_test_scores['f1_score'], em_nb_test_scores['f1_score'], color='lightgreen')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('F1 Score')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Test F1 Score vs Number of Labeled Documents in Training Set')

# %%
# Plot and compare test recall and precisions metrics
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121)
ax1.plot(experiments, nb_test_scores['recall'], color='b', marker='s', linestyle='-.', linewidth=2, label='Traditional Naive Bayes')
ax1.plot(experiments, em_nb_test_scores['recall'], color='r', marker='o', linestyle='-.', linewidth=2, label='Semisupervised EM Naive Bayes')
ax1.fill_between(experiments, nb_test_scores['recall'], em_nb_test_scores['recall'], color='pink')
ax1.set_xlabel('Number of Labeled Documents')
ax1.set_ylabel('Recall')
ax1.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax1.set_xscale('log')
ax1.set_xticks([200, 1000, 5000]) 
ax1.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)

ax2 = fig.add_subplot(122)
ax2.plot(experiments, nb_test_scores['precision'], color='b', marker='s', linestyle=':', linewidth=2, label='Traditional Naive Bayes')
ax2.plot(experiments, em_nb_test_scores['precision'], color='r', marker='o', linestyle=':', linewidth=2, label='Semisupervised EM Naive Bayes')
ax2.fill_between(experiments, nb_test_scores['precision'], em_nb_test_scores['precision'], color='aqua')
ax2.set_xlabel('Number of Labeled Documents')
ax2.set_ylabel('Precision')
ax2.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax2.set_xscale('log')
ax2.set_xticks([200, 1000, 5000]) 
ax2.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
fig.suptitle('Test Recall and Precision vs Number of Labeled Documents in Training Set')
plt.show()

# %%
show_topK(nb_clf, vectorizer, category_names, K=30) # keywords for each class by original NB classifier
# Out:
# alt.atheism: thing way ani mani becaus ha christian statement doe delet exist religi post make claim know mean islam religion believ say atheism think wa moral peopl belief atheist thi god
# comp.graphics: tiff anim color version like inform wa softwar comput need code map ftp program convert bite doe anyon look pleas gif know use thi thank ani format file imag graphic
# comp.os.ms-windows.misc: pc ha like ax work microsoft mous printer doe know ftp font cica ani card anyon win tri os run program version disk thank problem thi use driver file window
# comp.sys.ibm.pc.hardware: need know irq buy ha modem anyon monitor doe work bio driver pc mb pleas port motherboard thank disk dx bu problem control ani ide use thi card scsi drive
# comp.sys.mac.hardware: lc upgrad softwar comput powerbook centri mhz like disk scsi acceler video know doe ha thank mb anyon ani work card simm use quadra problem monitor thi drive appl mac
# comp.windows.x: librari doe look like tri color user appreci compil faq manag client thank pleas sun problem mit xterm ani applic display run server file program motif widget thi use window
# misc.forsale: follow pay make control book meg thi card email disk use packag game brand edu manual mail origin cd ask condit includ drive price pleas new ship offer sell sale
# rec.autos: time wheel month oil honda road use make model anyon auto dealer problem ford new look year know brake price ani good like buy think drive engin thi wa car
# rec.motorcycles: counterst onli good leave ani turn guy seat drive road bmw ha buy say right know thing look dog rider make helmet like think dod thi motorcycl wa ride bike
# rec.sport.baseball: onli lose sox season philli yanke time make score bat pitcher morri say good ha play run fan think player hi hit win thi pitch year wa basebal team game
# rec.sport.hockey: detroit penguin coach toronto shoot devil onli like ranger bruin think leagu fan ha season year hi win score goal thi playoff espn nhl player wa play hockey team game
# sci.crypt: ani privaci think like messag number say public peopl wa bite ha tap make wiretap nsa know crypto law escrow secur algorithm phone use govern thi chip clipper encrypt key
# sci.electronics: good lead thing wire signal help line copi need compani sure wa power inform make phone thank ha like output batteri doe anyon know ani circuit chip work thi use
# sci.med: pitt problem geb gordon doe edu studi anyon like pain think time peopl patient cancer caus treatment use ani food ha msg know drug doctor effect medic diseas wa thi
# sci.space: someon rocket sky actual earth lunar whi hst say program fund onli ha make year someth know use moon shuttl think like mission nasa satellit orbit thi launch wa space
# soc.religion.christian: becaus read make like exist mean time whi come ha book word know peopl heaven love believ faith think bibl say hi christ church sin jesu thi wa christian god
# talk.politics.guns: ha claim ani compound koresh children firearm ga crimin crime use believ state think like know govern law shoot batf make say right bd weapon fbi peopl thi wa gun
# talk.politics.mideast: war make think know land polici ha like villag bosnia nation whi peac right attack turkish hi jewish say peopl kill palestinian muslim wa thi jew arab armenian isra israel
# talk.politics.misc: onli whi ani drug clinton know use law american time like men right sex govern ha batf think hi presid mr say gay state tax make homosexu peopl wa thi
# talk.religion.misc: mani object belief teach let want evid christ life children make moral point know religion ha peopl mean hi bibl word think koresh wa believ say thi jesu christian god

# %%
show_topK(em_nb_clf, vectorizer, category_names, K=30) # keywords for each class by semisupervised EM NB classifier
# Out:
# alt.atheism: delet thing reason agre statement ani becaus claim whi argument christian mean post object know make exist believ islam atheism belief wa religion peopl atheist think say moral god thi
# comp.graphics: edu inform sourc mail site help comput like color softwar need code bite convert ftp doe anyon gif look pleas know use program thi ani format thank file graphic imag
# comp.os.ms-windows.misc: ha like doe edu cica microsoft tri work pc disk know card anyon ftp win printer ms ani thank run version font os problem program thi driver use file window
# comp.sys.ibm.pc.hardware: anyon pleas set doe modem ha know mhz bio driver monitor board work port pc motherboard problem thank ani mb dx disk control bu use ide thi scsi card drive
# comp.sys.mac.hardware: board disk cabl machin price video comput like buy lc mhz centri doe quadra work know mb ha problem ani anyon thank simm card use thi monitor drive appl mac
# comp.windows.x: color user anyon like look help doe pleas code know set work mit problem client sun thank xterm ani display applic program file run widget motif server thi use window
# misc.forsale: old box pay thi make card packag best brand game excel origin edu disk manual email cd use drive mail ask includ new price pleas condit ship sell offer sale
# rec.autos: veri road time honda price make problem speed model year mile look ha oil good use auto think new know buy ford dealer like ani drive thi wa engin car
# rec.motorcycles: drink realli thing onli use time say new right drive ha road look ani good buy make know think bmw helmet dog rider like thi dod wa motorcycl ride bike
# rec.sport.baseball: sox leagu like know say score brave hitter play time fan good ball season ha bat run think pitcher win player basebal thi hi hit pitch team wa year game
# rec.sport.hockey: watch detroit know time ranger coach like leagu leaf bruin pen ha fan score hi think win nhl year goal thi season espn playoff player play wa hockey team game
# sci.crypt: privaci agenc secret messag ani say wa crypto wiretap think like bite public ha make peopl law know algorithm escrow nsa phone secur govern use clipper thi chip encrypt key
# sci.electronics: help signal look ha compani wire radio current need amp wa line output phone power make thank doe voltag batteri like work anyon know electron chip ani circuit thi use
# sci.med: intellect time cadr chastiti dsl jxp think pitt skeptic geb pain gordon test treatment drug like use food msg caus know ani ha effect medic patient diseas doctor wa thi
# sci.space: lunar program develop project rocket thing solar hst make fund ha time cost know sky earth year mission think satellit like use moon shuttl nasa launch thi wa orbit space
# soc.religion.christian: read scriptur ani doe question whi make ha love book come word mean life faith know peopl think christ believ bibl sin church say hi jesu wa thi christian god
# talk.politics.guns: start crimin whi ha children compound use bd kill state crime shoot ani know firearm koresh like make batf think govern say weapon law right peopl fbi thi wa gun
# talk.politics.mideast: peac like turkey turk genocid know nation countri govern attack right hi nazi war state ha palestinian turkish jewish say kill peopl muslim thi wa jew isra arab israel armenian
# talk.politics.misc: sexual use clinton want know becaus time health year law drug men ani hi mr ha presid like right think govern gay make state tax say homosexu wa peopl thi
# talk.religion.misc: evid onli use thing children want mormon whi rosicrucian point mean know ha word cheer make religion bibl peopl hi think believ koresh kent wa jesu say thi christian god
