# %% [markdown]
# Update: Increase experiment points. Study the relation between classification accuracy and quantity of labeled and unlabeled documents.

# %%
# Import packages and libraries
import numpy as np
import random as rnd
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, StratifiedKFold, ShuffleSplit
from sklearn import metrics

from time import time
from pprint import pprint
from copy import deepcopy
from wordcloud import WordCloud 
from Semi_EM_NB import Semi_EM_MultinomialNB
from os import path
from PIL import Image

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
def remove_noise(sentence):
    result = ''
    poster = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    stopword_set = set(stopwords.words('english'))
    wordlist = re.sub(r"\n|(\\(.*?){)|}|[!$%^&*#()_+|~\-={}\[\]:\";'<>?,.\/\\]|[0-9]|[@]", ' ', sentence) # remove punctuation
    wordlist = re.sub('\s+', ' ', wordlist) # remove extra space
    wordlist_normal = [poster.stem(word.lower()) for word in wordlist.split()] # restore word to its original form (stemming)
    wordlist_normal = [lemmatizer.lemmatize(word, pos='v') for word in wordlist_normal] # restore word to its root form (lemmatization)
    wordlist_clean = [word for word in wordlist_normal if word not in stopword_set] # remove stopwords
    result = ' '.join(wordlist_clean)
    return result

# %%
def cross_validation(clf, data_X, data_y, unlabeled=None, n_folds=5):
    print('=' * 80)
    print("Validation: ")
    print(clf)
    kf = StratifiedKFold(n_splits=n_folds)
    start_time = time()
    train_scores = list() # training accuracy
    fold_count = 1
    original_clf = deepcopy(clf)
    avg_accuracy = 0
    for train_ids, valid_ids in kf.split(data_X, data_y):
        cv_clf = deepcopy(original_clf)
        print("Fold # %d" % fold_count)
        fold_count += 1
        train_X, train_y, valid_X, valid_y = data_X[train_ids], data_y[train_ids], data_X[valid_ids], data_y[valid_ids]
        if unlabeled==None:
            cv_clf.fit(train_X, train_y)
        else:
            cv_clf.fit(train_X, train_y, unlabeled)
        pred = cv_clf.predict(valid_X)
        scores = dict()
        scores['accuracy'] = metrics.accuracy_score(valid_y, pred)
        scores['recall'] = metrics.recall_score(valid_y, pred, average='macro')
        scores['precision'] = metrics.precision_score(valid_y, pred, average='macro')
        scores['f1_score'] = metrics.f1_score(valid_y, pred, average='macro')
        train_scores.append(scores)
        avg_accuracy += scores['accuracy']
    train_time = time() - start_time
    print("Validation time: %0.3f seconds" % train_time)
    print("Average training accuracy: %0.3f" % (avg_accuracy/n_folds))
    return train_scores, train_time

# %%
def show_topK(classifier, vectorizer, categories, K=10):
    feature_names = np.asarray(vectorizer.get_feature_names())
    nrows, ncols = 5, 4
    fig, axes = plt.subplots(figsize=(50, 40), nrows=nrows, ncols=ncols)
    #d = path.dirname(__file__)
    circle_mask = np.array(Image.open(path.join('./', "circle.png")))
    for i, category in enumerate(categories):
        topK = np.argsort(classifier.coef_[i])[-K:]
        text = " ".join(feature_names[topK])
        print("%s: %s" % (category, text))
        wordcloud = WordCloud(background_color="white", mask=circle_mask).generate(text)
        axes[i//ncols, i%ncols].imshow(wordcloud, cmap=plt.cm.cool_r, interpolation='bilinear')
        axes[i//ncols, i%ncols].axis("off")
        axes[i//ncols, i%ncols].set_title(category, fontweight="bold", size=24)
    plt.show()

# %%
# Load data set with class labels and split into train and test set
test_size_ratio = 0.2
data_Xy = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'), shuffle=True)
category_names = data_Xy.target_names # text names of all categories
train_X, test_X, train_y, test_y = train_test_split(data_Xy.data, data_Xy.target, test_size=test_size_ratio, stratify=data_Xy.target)
print("Training set size: %8d\tTest set size: %8d" % (len(train_X), len(test_X)))
# Out:
# Training set size:    15076	Test set size:     3770

# %%
# preprocess train and test text data
train_X_clean = map(remove_noise, train_X)
test_X_clean = map(remove_noise, test_X)

# %%
# Convert all text data into tf-idf vectors 
vectorizer = TfidfVectorizer(stop_words='english', min_df=5, max_df=0.95)
# vectorizer = TfidfVectorizer()
train_vec = vectorizer.fit_transform(train_X_clean)
test_vec = vectorizer.transform(test_X_clean)
print train_vec.shape, test_vec.shape
# Out:
# (15076, 13162) (3770, 13162)

# %%
# Divide train data set into labeled and unlabeled data sets
split_ratio = 0.2 # labeled vs total(labeled+unlabeled)
# X_l, X_u, y_l, y_u = train_test_split(train_vec, train_y, train_size=split_ratio, stratify=train_y)
X_l, X_u, y_l, y_u = train_test_split(train_vec, train_y, test_size=10000, stratify=train_y)
experiments = np.logspace(2.3, 3.7, num=20, base=10, dtype='int')
print X_l.shape, X_u.shape
# Out:
# (5076, 13162) (10000, 13162)

# %%
# Cross validation for Naive Bayes classifier 
# using labeled data set only
nb_cv_scores = list()
nb_cv_times = list()
for n_l_docs in experiments:
    nb_clf = MultinomialNB(alpha=1e-2)
    cv_scores, cv_time = cross_validation(nb_clf, X_l[:n_l_docs,], y_l[:n_l_docs])
    nb_cv_scores.append(cv_scores)
    nb_cv_times.append(cv_time)
    print("Number of labeled documents: %6d" % n_l_docs)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.072 seconds
# Average training accuracy: 0.393
# Number of labeled documents:    199
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.049 seconds
# Average training accuracy: 0.437
# Number of labeled documents:    236
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.049 seconds
# Average training accuracy: 0.402
# Number of labeled documents:    280
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.051 seconds
# Average training accuracy: 0.449
# Number of labeled documents:    331
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.054 seconds
# Average training accuracy: 0.451
# Number of labeled documents:    393
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.052 seconds
# Average training accuracy: 0.487
# Number of labeled documents:    466
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.053 seconds
# Average training accuracy: 0.502
# Number of labeled documents:    552
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.056 seconds
# Average training accuracy: 0.551
# Number of labeled documents:    654
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.057 seconds
# Average training accuracy: 0.551
# Number of labeled documents:    775
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.058 seconds
# Average training accuracy: 0.596
# Number of labeled documents:    918
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.059 seconds
# Average training accuracy: 0.615
# Number of labeled documents:   1088
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.064 seconds
# Average training accuracy: 0.608
# Number of labeled documents:   1289
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.065 seconds
# Average training accuracy: 0.609
# Number of labeled documents:   1528
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.069 seconds
# Average training accuracy: 0.624
# Number of labeled documents:   1810
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.075 seconds
# Average training accuracy: 0.635
# Number of labeled documents:   2145
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.076 seconds
# Average training accuracy: 0.658
# Number of labeled documents:   2542
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.082 seconds
# Average training accuracy: 0.666
# Number of labeled documents:   3012
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.091 seconds
# Average training accuracy: 0.676
# Number of labeled documents:   3569
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.094 seconds
# Average training accuracy: 0.691
# Number of labeled documents:   4229
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.107 seconds
# Average training accuracy: 0.695
# Number of labeled documents:   5011
# /Users/Jerry/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Jerry/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Cross validation for semisupervised EM Naive Bayes classifier 
# using both labeled and unlabeled data set
em_nb_cv_scores = list()
em_nb_cv_times = list()
for n_l_docs in experiments:
    em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False) # semi supervised EM based Naive Bayes classifier
    cv_scores, cv_time = cross_validation(em_nb_clf, X_l[:n_l_docs,], y_l[:n_l_docs], X_u)
    em_nb_cv_scores.append(cv_scores)
    em_nb_cv_times.append(cv_time)
    print("Number of labeled documents: %6d" % n_l_docs)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 158.963 seconds
# Average training accuracy: 0.477
# Number of labeled documents:    199
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 153.514 seconds
# Average training accuracy: 0.482
# Number of labeled documents:    236
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 129.077 seconds
# Average training accuracy: 0.513
# Number of labeled documents:    280
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 118.870 seconds
# Average training accuracy: 0.549
# Number of labeled documents:    331
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 101.246 seconds
# Average training accuracy: 0.561
# Number of labeled documents:    393
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 108.219 seconds
# Average training accuracy: 0.563
# Number of labeled documents:    466
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 93.686 seconds
# Average training accuracy: 0.575
# Number of labeled documents:    552
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 86.710 seconds
# Average training accuracy: 0.602
# Number of labeled documents:    654
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 78.933 seconds
# Average training accuracy: 0.621
# Number of labeled documents:    775
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 78.190 seconds
# Average training accuracy: 0.627
# Number of labeled documents:    918
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 73.801 seconds
# Average training accuracy: 0.649
# Number of labeled documents:   1088
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 74.101 seconds
# Average training accuracy: 0.673
# Number of labeled documents:   1289
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 64.263 seconds
# Average training accuracy: 0.663
# Number of labeled documents:   1528
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 61.277 seconds
# Average training accuracy: 0.672
# Number of labeled documents:   1810
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 63.744 seconds
# Average training accuracy: 0.673
# Number of labeled documents:   2145
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 63.921 seconds
# Average training accuracy: 0.679
# Number of labeled documents:   2542
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 62.104 seconds
# Average training accuracy: 0.693
# Number of labeled documents:   3012
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 76.046 seconds
# Average training accuracy: 0.693
# Number of labeled documents:   3569
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 70.801 seconds
# Average training accuracy: 0.698
# Number of labeled documents:   4229
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 75.277 seconds
# Average training accuracy: 0.700
# Number of labeled documents:   5011

# %%
# plot CV accuracy comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['accuracy'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['accuracy'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_score_mean, color='b', linewidth=2, label='Traditional Naive Bayes')
ax.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax.plot(experiments, em_nb_score_mean, color='r', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Accuracy')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Cross-Validation Average Accuracy vs Number of Labeled Documents in Training Set')

# %%
# plot CV F1 Score comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['f1_score'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['f1_score'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_score_mean, color='b', linestyle='--', linewidth=2, label='Traditional Naive Bayes')
ax.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax.plot(experiments, em_nb_score_mean, color='r', linestyle='--', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='lightgreen')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('F1 Score')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Cross-Validation Average F1 Score vs Number of Labeled Documents in Training Set')

# %%
# plot CV accuracy comparisons
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['recall'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['recall'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_subplot(121)
ax1.plot(experiments, nb_score_mean, color='b', linestyle='-.', linewidth=2, label='Traditional Naive Bayes')
ax1.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax1.plot(experiments, em_nb_score_mean, color='r', linestyle='-.', linewidth=2, label='Semisupervised EM Naive Bayes')
ax1.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax1.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='pink')
ax1.set_xlabel('Number of Labeled Documents')
ax1.set_ylabel('Recall')
ax1.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax1.set_xscale('log')
ax1.set_xticks([200, 1000, 5000]) 
ax1.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
nb_score_mean = list()
nb_score_err = list()
em_nb_score_mean = list()
em_nb_score_err = list()
for idx in range(len(experiments)):
    nb_scores = [value['precision'] for value in nb_cv_scores[idx]]
    nb_score_mean.append(np.mean(nb_scores))
    nb_score_err.append(np.std(nb_scores))
    em_nb_scores = [value['precision'] for value in em_nb_cv_scores[idx]]
    em_nb_score_mean.append(np.mean(em_nb_scores))
    em_nb_score_err.append(np.std(em_nb_scores))
ax2 = fig.add_subplot(122)
ax2.plot(experiments, nb_score_mean, color='b', linestyle=':', linewidth=2, label='Traditional Naive Bayes')
ax2.errorbar(experiments, nb_score_mean, yerr=nb_score_err, fmt='s', color='b')
ax2.plot(experiments, em_nb_score_mean, color='r', linestyle=':', linewidth=2, label='Semisupervised EM Naive Bayes')
ax2.errorbar(experiments, em_nb_score_mean, yerr=em_nb_score_err, fmt='o', color='r')
ax2.fill_between(experiments, nb_score_mean, em_nb_score_mean, color='aqua')
ax2.set_xlabel('Number of Labeled Documents')
ax2.set_ylabel('Precision')
ax2.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax2.set_xscale('log')
ax2.set_xticks([200, 1000, 5000]) 
ax2.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
fig.suptitle('Cross-Validation Recall and Precision vs Number of Labeled Documents in Training Set')
plt.show()

# %%
# plot time consuming in EM NB training process
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_cv_times, color='b', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_cv_times, color='r', linestyle='-', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.fill_between(experiments, nb_cv_times, em_nb_cv_times, color='beige')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Time (seconds)')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.title('Time consumed in  vs Number of Labeled Documents in Training Set')

# %%
# Evaluate original NB classifier using test data set
nb_test_scores = dict()
nb_test_scores['accuracy'] = list()
nb_test_scores['recall'] = list()
nb_test_scores['precision'] = list()
nb_test_scores['f1_score'] = list()
for n_l_docs in experiments:
    nb_clf = MultinomialNB(alpha=1e-2).fit(X_l[:n_l_docs,], y_l[:n_l_docs])
    pred = nb_clf.predict(test_vec)
    accuracy = metrics.accuracy_score(test_y, pred)
    nb_test_scores['accuracy'].append(accuracy)
    nb_test_scores['recall'].append(metrics.recall_score(test_y, pred, average='macro'))
    nb_test_scores['precision'].append(metrics.precision_score(test_y, pred, average='macro'))
    nb_test_scores['f1_score'].append(metrics.f1_score(test_y, pred, average='macro'))
    print("%6d labeled documents lead to accuracy of %.3f" % (n_l_docs, accuracy))
# Out:
#    199 labeled documents lead to accuracy of 0.367
#    236 labeled documents lead to accuracy of 0.402
#    280 labeled documents lead to accuracy of 0.434
#    331 labeled documents lead to accuracy of 0.462
#    393 labeled documents lead to accuracy of 0.480
#    466 labeled documents lead to accuracy of 0.502
#    552 labeled documents lead to accuracy of 0.519
#    654 labeled documents lead to accuracy of 0.534
#    775 labeled documents lead to accuracy of 0.559
#    918 labeled documents lead to accuracy of 0.578
#   1088 labeled documents lead to accuracy of 0.598
#   1289 labeled documents lead to accuracy of 0.615
#   1528 labeled documents lead to accuracy of 0.624
#   1810 labeled documents lead to accuracy of 0.640
#   2145 labeled documents lead to accuracy of 0.654
#   2542 labeled documents lead to accuracy of 0.669
#   3012 labeled documents lead to accuracy of 0.683
#   3569 labeled documents lead to accuracy of 0.700
#   4229 labeled documents lead to accuracy of 0.704
#   5011 labeled documents lead to accuracy of 0.708

# %%
# Evaluate semi-supervised EM NB classifier using test data set
em_nb_test_scores = dict()
em_nb_test_scores['accuracy'] = list()
em_nb_test_scores['recall'] = list()
em_nb_test_scores['precision'] = list()
em_nb_test_scores['f1_score'] = list()
for n_l_docs in experiments:
    em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False).fit(X_l[:n_l_docs,], y_l[:n_l_docs], X_u)
    pred = em_nb_clf.predict(test_vec)
    accuracy = metrics.accuracy_score(test_y, pred)
    em_nb_test_scores['accuracy'].append(accuracy)
    em_nb_test_scores['recall'].append(metrics.recall_score(test_y, pred, average='macro'))
    em_nb_test_scores['precision'].append(metrics.precision_score(test_y, pred, average='macro'))
    em_nb_test_scores['f1_score'].append(metrics.f1_score(test_y, pred, average='macro'))
    print("%6d labeled documents lead to accuracy of %.3f" % (n_l_docs, accuracy))
# Out:
#    199 labeled documents lead to accuracy of 0.485
#    236 labeled documents lead to accuracy of 0.503
#    280 labeled documents lead to accuracy of 0.573
#    331 labeled documents lead to accuracy of 0.583
#    393 labeled documents lead to accuracy of 0.580
#    466 labeled documents lead to accuracy of 0.606
#    552 labeled documents lead to accuracy of 0.611
#    654 labeled documents lead to accuracy of 0.619
#    775 labeled documents lead to accuracy of 0.636
#    918 labeled documents lead to accuracy of 0.636
#   1088 labeled documents lead to accuracy of 0.653
#   1289 labeled documents lead to accuracy of 0.658
#   1528 labeled documents lead to accuracy of 0.668
#   1810 labeled documents lead to accuracy of 0.678
#   2145 labeled documents lead to accuracy of 0.688
#   2542 labeled documents lead to accuracy of 0.692
#   3012 labeled documents lead to accuracy of 0.702
#   3569 labeled documents lead to accuracy of 0.709
#   4229 labeled documents lead to accuracy of 0.711
#   5011 labeled documents lead to accuracy of 0.711

# %%
# Plot and compare test accuracy metrics
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_test_scores['accuracy'], color='b', marker='s', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_test_scores['accuracy'], color='r', marker='o', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('Accuracy')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Test Accuracy vs Number of Labeled Documents in Training Set')

# %%
# Plot and compare test f1 score metrics
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(experiments, nb_test_scores['f1_score'], color='b', marker='s', linestyle='--', linewidth=2, label='Traditional Naive Bayes')
ax.plot(experiments, em_nb_test_scores['f1_score'], color='r', marker='o', linestyle='--', linewidth=2, label='Semisupervised EM Naive Bayes')
ax.fill_between(experiments, nb_test_scores['f1_score'], em_nb_test_scores['f1_score'], color='lightgreen')
ax.set_xlabel('Number of Labeled Documents')
ax.set_ylabel('F1 Score')
ax.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax.set_xscale('log')
ax.set_xticks([200, 1000, 5000]) 
ax.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
plt.legend(loc='upper left')
plt.title('Test F1 Score vs Number of Labeled Documents in Training Set')

# %%
# Plot and compare test recall and precisions metrics
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121)
ax1.plot(experiments, nb_test_scores['recall'], color='b', marker='s', linestyle='-.', linewidth=2, label='Traditional Naive Bayes')
ax1.plot(experiments, em_nb_test_scores['recall'], color='r', marker='o', linestyle='-.', linewidth=2, label='Semisupervised EM Naive Bayes')
ax1.fill_between(experiments, nb_test_scores['recall'], em_nb_test_scores['recall'], color='pink')
ax1.set_xlabel('Number of Labeled Documents')
ax1.set_ylabel('Recall')
ax1.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax1.set_xscale('log')
ax1.set_xticks([200, 1000, 5000]) 
ax1.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)

ax2 = fig.add_subplot(122)
ax2.plot(experiments, nb_test_scores['precision'], color='b', marker='s', linestyle=':', linewidth=2, label='Traditional Naive Bayes')
ax2.plot(experiments, em_nb_test_scores['precision'], color='r', marker='o', linestyle=':', linewidth=2, label='Semisupervised EM Naive Bayes')
ax2.fill_between(experiments, nb_test_scores['precision'], em_nb_test_scores['precision'], color='aqua')
ax2.set_xlabel('Number of Labeled Documents')
ax2.set_ylabel('Precision')
ax2.set_xlim(left=np.min(experiments)-10, right=np.max(experiments)+100)
ax2.set_xscale('log')
ax2.set_xticks([200, 1000, 5000]) 
ax2.set_xticklabels([r'$2\times10^2$', r'$10^3$', r'$5\times10^3$'], fontsize=15)
fig.suptitle('Test Recall and Precision vs Number of Labeled Documents in Training Set')
plt.show()

# %%
show_topK(nb_clf, vectorizer, category_names, K=30) # keywords for each class by original NB classifier
# Out:
# alt.atheism: object whi punish onli becaus consid atheism ani exist ha thing mean argument doe belief delet know post islam moral make believ wa peopl religion think thi god say atheist
# comp.graphics: need run comput display work like softwar version color mail code polygon pleas doe help bite anyon gif know point look thank program format use thi ani file imag graphic
# comp.os.ms-windows.misc: memori applic print know pc disk version help pleas mous wa work like card problem thank ani win microsoft run os ms font thi ax program driver use file window
# comp.sys.ibm.pc.hardware: mhz set pin buy work pleas machin anyon modem driver scsi control ide ha board motherboard dx pc mb problem know thank ani monitor comput use bu thi drive card
# comp.sys.mac.hardware: speed centri mb duo power buy machin scsi like upgrad ha lc new disk know work mhz doe thank video ani anyon simm problem use thi monitor drive appl mac
# comp.windows.x: pleas code color sourc anyon hi compil look tri like problem know doe client sun manag applic ha thank ani file program motif widget run display server thi use window
# misc.forsale: make ha origin repli packag forsal cd thank box pay thi card edu manual drive mail ask use condit game disk new email pleas includ price sell ship offer sale
# rec.autos: mile look doe problem radar veri toyota ha want speed price auto make new think use like know year oil drive good dealer ani ford buy thi wa engin car
# rec.motorcycles: guy road new time wave onli look know thing ani buy tri rider bmw mile realli make drive good think say helmet dog like motorcycl thi dod wa ride bike
# rec.sport.baseball: becaus guy good brave say better bat leagu stat know ball score time ha season play think win run pitcher basebal player thi pitch hi team wa hit year game
# rec.sport.hockey: realli pen wing know island leagu sport say like ha bruin trade leaf fan win think season score hi espn nhl year thi playoff hockey player wa play team game
# sci.crypt: say make ani inform right privaci law secret wiretap like onli public peopl algorithm wa crypto ha know bite escrow phone secur nsa use govern thi clipper chip encrypt key
# sci.electronics: comput suppli design make wa number like amp look input output batteri compani good lead devic radio nois electron know voltag copi chip power anyon ani doe circuit thi use
# sci.med: pain ani peopl use think caus treatment doctor drug bank know shame surrend skeptic ha pitt intellect gordon cadr chastiti jxp dsl geb food msg diseas effect wa patient thi
# sci.space: idea imag sci long flight mass good lunar moon fund ha program spacecraft earth project hst think sky know like mission satellit use shuttl launch wa nasa thi orbit space
# soc.religion.christian: like scriptur make exist mean whi word ha doe life mari ani think come cathol peopl know believ christ say bibl sin faith hi church wa jesu thi christian god
# talk.politics.guns: death time know atf davidian thing use state crimin make start firearm onli ani batf bd shoot koresh govern like think right say peopl fbi law weapon thi wa gun
# talk.politics.mideast: state want right nation peac attack hi know turk make massacr turkey ha countri war palestinian jewish turkish nazi kill say peopl thi muslim jew isra wa arab israel armenian
# talk.politics.misc: use polit sexual american job hi sex clinton drug ani nation time right ha forc mani presid make like men tax say govern think state homosexu gay wa peopl thi
# talk.religion.misc: use want doe kent christ theori fact faith whi agre know rosicrucian delet mean person bibl religion word point believ moral peopl think say jesu wa hi christian thi god

# %%
show_topK(em_nb_clf, vectorizer, category_names, K=30) # keywords for each class by semisupervised EM NB classifier
# Out:
# alt.atheism: point whi evid becaus thing statement claim doe ani know mean argument atheism delet object belief islam post make peopl exist religion wa believ think atheist moral say thi god
# comp.graphics: point need like site display comput advanc softwar mail convert help ftp code doe color bite look gif pleas use know anyon ani format thi program thank file graphic imag
# comp.os.ms-windows.misc: doe anyon cica help pc tri printer microsoft mous disk know like ftp ms zip work win problem version os ani run thank program thi font driver use file window
# comp.sys.ibm.pc.hardware: doe bio pleas mhz comput ha driver anyon know work motherboard modem pc disk port board monitor problem ani thank control ide dx mb bu use scsi thi card drive
# comp.sys.mac.hardware: softwar new like comput machin price mb lc video quadra upgrad centri mhz simm doe card disk know work ha anyon ani thank problem use monitor thi drive appl mac
# comp.windows.x: ha pleas know tri work help color manag code mit doe set like problem client sun xterm applic file thank ani display program run widget motif server thi use window
# misc.forsale: make like box thi brand thank packag pay origin excel card drive manual disk game edu cd use email mail ask new condit includ price pleas ship sell offer sale
# rec.autos: tire want problem time make sell oil veri year speed look price good use think auto mile ha dealer ani new drive buy know ford like engin thi wa car
# rec.motorcycles: thing use way rear time wheel new look right road buy say ani bmw car make drive know good rider think helmet dog like thi motorcycl dod wa ride bike
# rec.sport.baseball: cub good like fan brave score hitter say leagu ha time stat season ball bat play run think pitcher win thi basebal player hi hit year team pitch wa game
# rec.sport.hockey: coach trade know sabr watch detroit time bruin like pen ha leaf score goal nhl think hi fan year season win espn playoff thi player hockey play wa team game
# sci.crypt: say secret onli messag wiretap bite right ani think public crypto make like law ha wa peopl know algorithm escrow phone nsa secur use govern clipper chip thi encrypt key
# sci.electronics: time current compani good look number output line wa make phone need thank work lead amp radio voltag know like doe anyon electron power batteri ani chip circuit thi use
# sci.med: studi think treatment infect intellect cadr chastiti jxp dsl skeptic use gordon pitt geb pain like drug ani know msg food caus medic patient ha effect diseas doctor wa thi
# sci.space: hst thing peopl rocket work ha make program sky time spacecraft cost solar year project know use like satellit earth think mission moon shuttl launch nasa wa thi orbit space
# soc.religion.christian: onli question homosexu doe like book word whi come ha make love mean life faith think know peopl christ believ bibl sin say church hi jesu wa thi christian god
# talk.politics.guns: children death start whi kill crimin compound use state shoot ani crime bd know like firearm make koresh govern think say right law batf weapon peopl thi fbi wa gun
# talk.politics.mideast: make think villag genocid countri ani attack turk turkey govern right state nazi ha hi war turkish jewish palestinian kill say peopl muslim thi isra jew wa arab israel armenian
# talk.politics.misc: becaus libertarian know want onli use time year american men mani mr drug ani law ha presid right like think make gay govern state tax say homosexu wa peopl thi
# talk.religion.misc: doe want order ani read ha mean religion person make fact rosicrucian know point theori word bibl moral believ cheer peopl jesu say think hi kent wa god thi christian

# %%
# details of classification accuracy metrics
print(metrics.classification_report(test_y, pred, target_names=category_names))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.62      0.49      0.55       160
#            comp.graphics       0.62      0.64      0.63       195
#  comp.os.ms-windows.misc       0.65      0.63      0.64       197
# comp.sys.ibm.pc.hardware       0.59      0.72      0.65       196
#    comp.sys.mac.hardware       0.74      0.73      0.73       193
#           comp.windows.x       0.83      0.80      0.82       198
#             misc.forsale       0.82      0.58      0.68       195
#                rec.autos       0.75      0.70      0.72       198
#          rec.motorcycles       0.80      0.72      0.76       199
#       rec.sport.baseball       0.93      0.82      0.87       199
#         rec.sport.hockey       0.61      0.94      0.74       200
#                sci.crypt       0.79      0.77      0.78       198
#          sci.electronics       0.76      0.64      0.70       197
#                  sci.med       0.87      0.78      0.82       198
#                sci.space       0.74      0.77      0.75       197
#   soc.religion.christian       0.60      0.85      0.70       199
#       talk.politics.guns       0.59      0.80      0.68       182
#    talk.politics.mideast       0.81      0.83      0.82       188
#       talk.politics.misc       0.62      0.57      0.59       155
#       talk.religion.misc       0.68      0.17      0.27       126
#
#              avg / total       0.72      0.71      0.71      3770

# %%
# plot confusion matrix for test dataset
plt.figure(figsize=(12,12))
sns.set()
sns.heatmap(metrics.confusion_matrix(test_y, pred), annot=True, fmt="d", linewidths=.5)
plt.title("Confusion Matrix")
